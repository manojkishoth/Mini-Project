# %%
import requests

# %%
url = "https://www.fast2sms.com/dev/bulkV2"

# %%
payload = "message=Bus(1)%20Will%20reach%20your%20boarding%20point%20in%207minutes&language=english&route=q&numbers=9500437641"
headers = {
    'authorization': "YAmQRc8xaHFovjuXnIZbyqC70Bw2WOVK1lr5PJtDdSNTi9gEfhM6bu8NviIFW4rmf9K32yAQqClJgetH",
    'Content-Type': "application/x-www-form-urlencoded",
    'Cache-Control': "no-cache",
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {"return":true,"request_id":"brazpeh60jkxu4g","message":["SMS sent successfully."]}

# %%
payload = {
"route" : "q",
"message" : "test sms",
"flash" : 0,
"numbers" : "9500437641",
































































































            }

# %%
headers = {
"authorization":"YAmQRc8xaHFovjuXnIZbyqC70Bw2WOVK1lr5PJtDdSNTi9gEfhM6bu8NviIFW4rmf9K32yAQqClJgetH",
"Content-Type":"application/json",
"Cache-Control": "no-cache",
}

# %%
response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {"return":false,"status_code":405,"message":"Numbers Missing"}
